# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    # MAE : 將兩個陣列相減後, 取絕對值(abs), 再將整個陣列加總成一個數字(sum), 最後除以y的長度(len), 因此稱為"平均絕對誤差"
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 150.225
# The Mean absolute error is 9.419

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# Ans:我選擇的這組資料是Crimes in Boston，藉由分析一個地方的犯罪資料能夠對於其之後的犯罪案件作預測與防範。此組資料重要的地方在於它對於當地的公眾利益/政策方向是很有參考性的。因為犯罪案件對於國民安全，例如搶劫案或是人質案件等等，還有國家安全，像是恐怖份子等等，觀察這些資料能夠看出各種案件的特質與常態，並去做一個分析來得出一個結論，有可能是之後警方會進行加強巡邏的時間與地點，或是針對預防犯罪，所提出的公共政策提案等等。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# Ans:犯罪事件報告為Boston Police Department (BPD)提供，蒐集其中警員們所紀錄的案件類型,發生地點,與時間。
#
# 3. 蒐集而來的資料型態為何
#
# Ans:為.csv，表格檔，記錄其案件編號,分類，詳細地點(街區,經緯度)，與詳細時間。
#
# 4. 這組資料想解決的問題如何評估
#
# Ans:哪種類型的犯罪案件最易發生? 與易發生的時間,地點? 還有犯罪量是隨著甚麼單位增加?(ex:年月日。
# 我認為可以藉由統計各類型的案件總次數來了解哪種案件或是時間與地點最易發生，但是增加程度則可以藉由將其每個單位的案件數量製成圖去做分析來達到預期的效果。(橫軸時間單位縱軸為此類型案件的發生次數)
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# Ans:假設載客地點與時間會影響車隊的業績，乘車人潮會於特定時間出現(例如：上下班時間,吃飯時間)，也有特定地點(例如吃飯時間的飯館,上班時的住債區與下班時的公司)，最不浪費客人與司機等待的時間(能夠一直接客)就是盡量將車派在密集點。那我們就定義，提升業績的方法便是找到絕佳的載客地點與載客時間並加大其時段地點的派車量。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# Ans:藉由取得每個車隊司機的載客資料(載客的時間地點)來做分析，讓他們將這些東西整理好並交給我。
#
# 3. 蒐集而來的資料型態為何
#
# Ans:可能會為表格式的，欄位陳列載客地點與時間。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
# Ans:累計每個地點陳列所有時間之所載客數，製成圖並找出高峰點，另一個則是每個時間陳列出各個地點的載客數，也是去找出高峰點，便為其最佳選擇。
